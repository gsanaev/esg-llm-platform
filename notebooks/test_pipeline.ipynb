# %%
import sys
sys.path.append("../src") 

from esg_system.core.pdf_reader import extract_text
from esg_user.pipeline.extract_kpis import extract_all_kpis
from esg_user.pipeline.normalize_kpis import normalize_kpis
from esg_user.pipeline.assemble_output import assemble_output

import json

pdf_path = "../data/raw/test_esg_report.pdf"

# Extract raw text from the PDF
text = extract_text(pdf_path)
print("Extracted text snippet:\n", text[:500], "...\n")

# Step 1: Regex + NLP + LLM (if configured)
raw_kpis = extract_all_kpis(text)
print("Raw KPIs:", raw_kpis)

# Step 2: Normalize units & values
normalized_kpis = normalize_kpis(raw_kpis)
print("Normalized KPIs:", normalized_kpis)

# Step 3: Assemble full output
final = assemble_output(
    normalized_kpis,
    source_pdf=pdf_path,
    extraction_method_version="v1"
)

print("Final Output:")
print(json.dumps(final, indent=2))

# %%
import sys
sys.path.append("../src") 

from esg_system.core.pdf_reader import extract_text
from esg_user.pipeline.extract_kpis import extract_all_kpis
from esg_user.pipeline.normalize_kpis import normalize_kpis
from esg_user.pipeline.assemble_output import assemble_output

import json

pdf_path = "../data/raw/test_esg_report.pdf"

# Extract raw text from the PDF
text = extract_text(pdf_path)
print("Extracted text snippet:\n", text[:500], "...\n")

# Step 1: Regex + NLP + LLM (if configured)
raw_kpis = extract_all_kpis(text)
print("Raw KPIs:", raw_kpis)

# Step 2: Normalize units & values
normalized_kpis = normalize_kpis(raw_kpis)
print("Normalized KPIs:", normalized_kpis)

# Step 3: Assemble full output
final = assemble_output(
    normalized_kpis,
    source_pdf=pdf_path,
    extraction_method_version="v1"
)

print("Final Output:")
print(json.dumps(final, indent=2))

# %%
import sys
sys.path.append("../src") 

from esg_system.core.pdf_reader import extract_text
from esg_user.pipeline.extract_kpis import extract_all_kpis
from esg_user.pipeline.normalize_kpis import normalize_kpis
from esg_user.pipeline.assemble_output import assemble_output

import json

pdf_path = "../data/raw/test_esg_report.pdf"

# Extract raw text from the PDF
text = extract_text(pdf_path)
print("Extracted text snippet:\n", text[:500], "...\n")

# Step 1: Regex + NLP + LLM (if configured)
raw_kpis = extract_all_kpis(text)
print("Raw KPIs:", raw_kpis)

# Step 2: Normalize units & values
normalized_kpis = normalize_kpis(raw_kpis)
print("Normalized KPIs:", normalized_kpis)

# Step 3: Assemble full output
final = assemble_output(
    normalized_kpis,
    source_pdf=pdf_path,
    extraction_method_version="v1"
)

print("Final Output:")
print(json.dumps(final, indent=2))
# Out:
# Extracted text snippet:
#  Our total greenhouse gas emissions in 2022 were 123,400 tCO2e.
# Total energy consumption reached 500,000 MWh in the fiscal year. ...
#
# Raw KPIs: {'total_ghg_emissions': {'value': 123400.0, 'unit': 'tCO2e'}, 'energy_consumption': {'value': 500000.0, 'unit': 'MWh'}, 'water_withdrawal': {'value': None, 'unit': None}}
# Normalized KPIs: {'total_ghg_emissions': {'value': 123400.0, 'unit': 'tCO2e'}, 'energy_consumption': {'value': 500000.0, 'unit': 'MWh'}, 'water_withdrawal': {'value': None, 'unit': 'm3'}}
# Final Output:
# {
#   "metadata": {
#     "timestamp": "2025-11-14T10:40:49.032814Z",
#     "schema_version": "universal_v1",
#     "extraction_method_version": "v1",
#     "source_pdf": "../data/raw/test_esg_report.pdf"
#   },
#   "kpi_results": {
#     "total_ghg_emissions": {
#       "value": 123400.0,
#       "unit": "tCO2e"
#     },
#     "energy_consumption": {
#       "value": 500000.0,
#       "unit": "MWh"
#     },
#     "water_withdrawal": {
#       "value": null,
#       "unit": "m3"
#     }
#   }
# }
