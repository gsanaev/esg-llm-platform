# %%
import sys
sys.path.append("../src") 

from esg_user.pipeline.extract_kpis import extract_all_kpis
from esg_user.pipeline.normalize_kpis import normalize_kpis
from esg_user.pipeline.assemble_output import assemble_output

text = """
    Our total greenhouse gas emissions in 2022 were 123,400 tCO2e.
    Total energy consumption reached 500,000 MWh in the fiscal year.
"""

raw = extract_all_kpis(text)
print("Raw:", raw)

normalized = normalize_kpis(raw)
print("Normalized:", normalized)

final = assemble_output(normalized, source_pdf="test.pdf")
print("Final:", final)
# Out:
# Raw: {'total_ghg_emissions': {'value': None, 'unit': None}, 'energy_consumption': {'value': None, 'unit': None}, 'water_withdrawal': {'value': None, 'unit': None}}
# Normalized: {'total_ghg_emissions': {'value': None, 'unit': 'tCO2e'}, 'energy_consumption': {'value': None, 'unit': 'MWh'}, 'water_withdrawal': {'value': None, 'unit': 'm3'}}
# Final: {'metadata': {'timestamp': '2025-11-14T09:25:50.205583Z', 'schema_version': 'universal_v1', 'extraction_method_version': 'v1', 'source_pdf': 'test.pdf'}, 'kpi_results': {'total_ghg_emissions': {'value': None, 'unit': 'tCO2e'}, 'energy_consumption': {'value': None, 'unit': 'MWh'}, 'water_withdrawal': {'value': None, 'unit': 'm3'}}}
