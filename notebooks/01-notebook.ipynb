# %%
from esg_user.extractors.regex_extractor import extract_kpis_regex

text = """
The company reported total GHG emissions of 120,500 tCO2e.
Energy consumption reached 5,000 MWh in 2023.
"""

print(extract_kpis_regex(text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from esg_user.extractors.regex_extractor import extract_kpis_regex
#       3 text = """
#       4 The company reported total GHG emissions of 120,500 tCO2e.
#       5 Energy consumption reached 5,000 MWh in 2023.
#       6 """
#       8 print(extract_kpis_regex(text))
#
# ModuleNotFoundError: No module named 'esg_user'
